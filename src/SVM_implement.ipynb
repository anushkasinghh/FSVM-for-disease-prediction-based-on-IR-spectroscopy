# %% [markdown]
#   Two distinct pipelines are interleaved in this notebook:
#
#   1. Maiti (2021) replication — SR extraction → PCA on each SR → ANOVA p-values → Cohen's d → SVM on PC scores (Cells 1–39)
#   2. Simple FSVM baseline — whole-spectrum FPCA inside LOOCV → SVM (Cells 44–50)
#
#   ---
#   1. Correctness
#
#   Critical Bugs
#
#   SR matrices use raw intensity, not baseline-corrected (Cell 5)
#   def extract_sr_matrix(df, start, end):
#       return np.stack(df['intensity'].apply(lambda x: x[mask]).values)
#   #                       ↑ raw, not 'intensity_baseline_corrected'
#   Same bug as PCA_ANOVA.ipynb. The pca_results dict, ANOVA heatmap (Cell 11), Cohen's d (Cell 34), scatter plots, and Cell 31 SVM all operate on uncorrected spectra. Only fsvm_loocv in Cells
#   46–50 correctly uses intensity_baseline_corrected.
#
#   Degenerate SVM result in Cell 31 goes unreported
#   Confusion matrix: [[26 0] [17 0]]
#   Sensitivity: 0.00, Specificity: 1.00, Balanced Accuracy: 0.50
#   The classifier predicts Healthy for every sample — a complete failure. The orientation flip logic runs but doesn't help because both group means are negative and close together. This result is
#    presented without comment or correction, which would be a red flag in any review.
#
#   Data leakage in Cell 31 SVM
#   pca_results (Cell 9) fits PCA on all 51 samples, then result_df is populated with those scores. Cell 31 runs LOOCV on these precomputed scores — meaning the test sample's spectrum already
#   influenced the PCA eigenvectors. The fsvm_loocv function in Cells 44–50 correctly avoids this by fitting PCA inside each fold.
#
#   ax.yaxis(0.05, 0.1) in Cell 38 is a call error
#   ax.yaxis(0.05, 0.1)   # AttributeError: 'YAxis' object is not callable
#   ax.yaxis is an axis attribute, not a method. Intent was ax.set_ylim(0.05, 0.1). The figure renders anyway in Jupyter because the error fires after the plot is drawn, but the y-axis is
#   unclipped.
#
#   Misleading title in Cell 16
#   Plot title says "SR 1170 cm⁻¹" but x/y axes plot SR_530_PC1 vs SR_530_PC3.
#
#   SR_1170 and SR_1190 windows overlap (10 cm⁻¹); SR_1190 and SR_1203 overlap (17 cm⁻¹)
#   - SR_1170: 1155–1185, SR_1190: 1175–1205 — share 1175–1185 cm⁻¹
#   - SR_1190: 1175–1205, SR_1203: 1188–1218 — share 1188–1205 cm⁻¹
#
#   PC scores from these SRs are correlated, so ANOVA tests on them are not independent.
#
#   ---
#   What is correct
#
#   fsvm_loocv (Cell 44) is methodologically sound
#   - Fits PCA on training fold only
#   - Projects test data using training mean and eigenvectors
#   - Orientation flip logic present
#   - Returns all relevant metrics including balanced accuracy
#
#   Cohen's d (Cell 34) is correctly implemented with pooled standard deviation:
#   sp = np.sqrt(((n0-1)*s0**2 + (n1-1)*s1**2) / (n0+n1-2))
#   Results: SR_1190_PC1 = −0.910, SR_1005_PC1 = −0.827 — large effect sizes, this is the most useful finding in the notebook.
#
#   Permutation test (Cell 35) is correctly designed — permutes labels, runs full LOOCV each time. p=0.057 (borderline).
#
#   Confidence ellipse (Cell 37) uses n_std=2.0 consistently, which is fine as a 2σ visualization — just needs to be labeled as "±2 SD" not "95% CI" (which needs chi-square scaling).
#
#   ---
#   Key results summary
#
#   ┌──────────────────────────────────┬──────────┬─────────────┬─────────────┬───────────────────┐
#   │              Method              │ Accuracy │ Sensitivity │ Specificity │   Balanced Acc    │
#   ├──────────────────────────────────┼──────────┼─────────────┼─────────────┼───────────────────┤
#   │ SR PC scores → SVM LOOCV, C=0.1  │ 0.60     │ 0.00        │ 1.00        │ 0.50 (degenerate) │
#   ├──────────────────────────────────┼──────────┼─────────────┼─────────────┼───────────────────┤
#   │ Whole-spectrum FSVM LOOCV, C=0.7 │ 0.814    │ 0.824       │ 0.808       │ 0.816             │
#   ├──────────────────────────────────┼──────────┼─────────────┼─────────────┼───────────────────┤
#   │ SR_1190 FSVM LOOCV, C=1500       │ 0.651    │ 1.00        │ 0.423       │ 0.712             │
#   ├──────────────────────────────────┼──────────┼─────────────┼─────────────┼───────────────────┤
#   │ Permutation test (all SR PC1-3)  │ 0.651    │ —           │ —           │ p=0.057           │
#   └──────────────────────────────────┴──────────┴─────────────┴─────────────┴───────────────────┘
#
#   The whole-spectrum result (Cell 47–48) is the strongest: balanced accuracy 0.816, sensitivity 0.824, specificity 0.808.
#
#   ---
#   2. Publication Readiness
#
#   Not ready as-is. Specific blockers:
#
#   ┌──────────────────────────────────────────────────────────────────────────┬──────────┐
#   │                                  Issue                                   │ Severity │
#   ├──────────────────────────────────────────────────────────────────────────┼──────────┤
#   │ Raw intensity in SR PCA/ANOVA                                            │ Critical │
#   ├──────────────────────────────────────────────────────────────────────────┼──────────┤
#   │ Degenerate Cell 31 result unreported                                     │ Critical │
#   ├──────────────────────────────────────────────────────────────────────────┼──────────┤
#   │ Data leakage in Cell 31 SVM                                              │ Critical │
#   ├──────────────────────────────────────────────────────────────────────────┼──────────┤
#   │ No C tuning inside LOOCV for fsvm_loocv (fixed manually at 0.7 and 1500) │ Major    │
#   ├──────────────────────────────────────────────────────────────────────────┼──────────┤
#   │ No class_weight="balanced" in fsvm_loocv despite 26/17 imbalance         │ Major    │
#   ├──────────────────────────────────────────────────────────────────────────┼──────────┤
#   │ Overlapping SR windows                                                   │ Major    │
#   ├──────────────────────────────────────────────────────────────────────────┼──────────┤
#   │ ax.yaxis(0.05, 0.1) bug, misleading title                                │ Minor    │
#   ├──────────────────────────────────────────────────────────────────────────┼──────────┤
#   │ 6 empty trailing cells                                                   │ Minor    │
#   └──────────────────────────────────────────────────────────────────────────┴──────────┘
#
#   What is worth keeping for publication:
#   - Cohen's d table (Cell 34) — strong discriminative signal found at SR_1190 and SR_1005
#   - Whole-spectrum fsvm_loocv result (Cells 47–48) — 0.816 balanced accuracy, clean LOOCV
#   - Mean ± std spectrum comparison (Cells 13, 24) — standard publication figures
#   - 3D Plotly ellipsoid (Cell 18) — useful for exploratory supplement
#
#   ---
#   3. What You've Missed
#
#   1. Nested cross-validation: C is hardcoded (0.7, 1500). The correct approach is an inner CV loop inside each LOOCV fold to select C — otherwise the C choice itself introduces bias.
#   2. No multiple-testing correction: ANOVA runs 7 SRs × 4 PCs = 28 tests. Without Bonferroni or FDR correction, any reported "significant" SR-PC is unreliable.
#   3. No ANOVA assumption checks: Shapiro-Wilk (normality) and Levene's test (equal variance) are not run before the F-test.
#   4. SR_530 result not discussed: SR_530 (acetaldehyde) has Cohen's d = −0.820 — nearly as strong as SR_1190. Maiti (2021) included this range; it should be explicitly analyzed and compared.
#   5. The 26/17 class imbalance is never handled in fsvm_loocv: The good sensitivity (0.824) from the whole-spectrum run may be misleading — a dummy majority classifier gives 0.605 accuracy and
#   0.0 sensitivity. Reporting balanced accuracy alongside accuracy is necessary.
#   6. Blind test never applied: The 23 blind samples are filtered in Cell 3 and never revisited. Any publication needs to evaluate on the blind set.
#   7. Comparison between pipelines is absent: The notebook produces two very different results (0.50 from SR-SVM vs 0.816 from FSVM) but never discusses why or which should be preferred.

# %% [markdown]
# ### Make Imports

# %%
import sys
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sys.path.append(os.path.abspath("/home/anushkasingh/Desktop/Thesis/Code/Baseline Correction"))
from load_data import read_data, create_combined_dataset
from baseline_correct import baseline_roy

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


from scipy.stats import f_oneway
import seaborn as sns

# %% [markdown]
# ### Create df

# %%
path = ["../ALLDataGross/allKgData",
    "../ALLDataGross/BlindData",
    "../ALLDataGross/healthyCohort"
]
normVP = [[504, 425, 451, 454, 450, 474, 451, 471, 540, 467,
    550, 468, 481, 450, 515, 441, 452, 462, 453, 450, 452, 
    490, 504, 520, 525, 498, 542, 527, 550],
        [505, 503, 478, 453, 460, 494, 410, 413, 479, 489, 
    473, 464, 445, 499, 406, 455, 481, 388, 428, 466, 463, 
    520, 461],
    [420, 420, 428, 448, 417, 430, 420, 449, 483, 499, 
    438, 465, 438, 428, 503, 505, 504, 454, 515, 441, 
    404, 363]]
infoP = [["H", "PC", "PC", "H", "PC", "BC", "PC", "PC", "BC", "BC", 
    "PC", "PC", "PC", "PC", "H", "H","PC", "PC", "KC", "PC", "KC", 
    "PC", "BC", "BC", "PC", "KC", "PC", "PC", "PC"],
        ["H", "H" ,"H" ,"H", "KG", "KG", "KG", "KG", "KG", "KG", "KG", "KG", "KG" ,
     "KG", "KG", "KG", "KG", "KG" ,"KG", "KG" ,"KG", "KG", "KG"],
          ["F", "M", "M", "F", "F", "F", "F", "M", "M", "M", 
    "M", "F", "M", "M", "F", "M" ,"M", "M", "M", "M", 
    "M", "M" ]
]
df = create_combined_dataset(path,normVP,infoP)

df['intensity_baseline_corrected'] = None
for idx, row in df.iterrows():
    df.at[idx, "intensity_baseline_corrected"], _, _ = baseline_roy(x=row["wavenumber"], y=row["intensity"], norm_factor_i=row['normVP'])
    print(f"{idx} done!")
print("baseline corrected!")
# Out:
# Folder exists: True
# Folder contents: [PosixPath('../ALLDataGross/allKgData/20190801-02-023.dpt'), PosixPath('../ALLDataGross/allKgData/dataLoadKGall.m'), PosixPath('../ALLDataGross/allKgData/20190801-01-022.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-04-012.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-03-024.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-05-004.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-12-010.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-10-018.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-05-013.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-07-028.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-04-003.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-09-017.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-03-002.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-06-014.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-02-001.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-13-021.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-03-011.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-08-029.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-12-020.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-06-005.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-10-008.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-04-025.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-11-019.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-11-009.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-06-027.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-09-007.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-08-006.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-05-026.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-08-016.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-07-015.dpt')]
# DPT files found: [PosixPath('../ALLDataGross/allKgData/20190801-02-023.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-01-022.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-04-012.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-03-024.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-05-004.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-12-010.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-10-018.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-05-013.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-07-028.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-04-003.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-09-017.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-03-002.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-06-014.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-02-001.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-13-021.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-03-011.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-08-029.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-12-020.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-06-005.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-10-008.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-04-025.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-11-019.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-11-009.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-06-027.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-09-007.dpt'), PosixPath('../ALLDataGross/allKgData/20190405-08-006.dpt'), PosixPath('../ALLDataGross/allKgData/20190801-05-026.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-08-016.dpt'), PosixPath('../ALLDataGross/allKgData/20190606-07-015.dpt')]
# ✅ Loaded 20190405-02-001.dpt with 2 columns
# ✅ Loaded 20190405-03-002.dpt with 2 columns
# ✅ Loaded 20190405-04-003.dpt with 2 columns
# ✅ Loaded 20190405-05-004.dpt with 2 columns
# ✅ Loaded 20190405-06-005.dpt with 2 columns
# ✅ Loaded 20190405-08-006.dpt with 2 columns
# ✅ Loaded 20190405-09-007.dpt with 2 columns
# ✅ Loaded 20190405-10-008.dpt with 2 columns
# ✅ Loaded 20190405-11-009.dpt with 2 columns
# ✅ Loaded 20190405-12-010.dpt with 2 columns
# ✅ Loaded 20190606-03-011.dpt with 2 columns
# ✅ Loaded 20190606-04-012.dpt with 2 columns
# ✅ Loaded 20190606-05-013.dpt with 2 columns
# ✅ Loaded 20190606-06-014.dpt with 2 columns
# ✅ Loaded 20190606-07-015.dpt with 2 columns
# ✅ Loaded 20190606-08-016.dpt with 2 columns
# ✅ Loaded 20190606-09-017.dpt with 2 columns
# ✅ Loaded 20190606-10-018.dpt with 2 columns
# ✅ Loaded 20190606-11-019.dpt with 2 columns
# ✅ Loaded 20190606-12-020.dpt with 2 columns
# ✅ Loaded 20190606-13-021.dpt with 2 columns
# ✅ Loaded 20190801-01-022.dpt with 2 columns
# ✅ Loaded 20190801-02-023.dpt with 2 columns
# ✅ Loaded 20190801-03-024.dpt with 2 columns
# ✅ Loaded 20190801-04-025.dpt with 2 columns
# ✅ Loaded 20190801-05-026.dpt with 2 columns
# ✅ Loaded 20190801-06-027.dpt with 2 columns
# ✅ Loaded 20190801-07-028.dpt with 2 columns
# ✅ Loaded 20190801-08-029.dpt with 2 columns
# Folder exists: True
# Folder contents: [PosixPath('../ALLDataGross/BlindData/20200925-20-045.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-19-044.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-03-BJ-TB.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-11-036.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-08-033.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-04-ÖG-TB.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-12-037.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-15-040.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-02-AA-DB.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-22-047.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-23-048.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-18-043.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-21-046.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-01-KM-02.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-14-039.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-17-042.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-05-030.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-10-035.dpt'), PosixPath('../ALLDataGross/BlindData/dataLoadKG20200925.m'), PosixPath('../ALLDataGross/BlindData/20200925-09-034.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-13-038.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-07-032.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-16-041.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-06-031.dpt')]
# DPT files found: [PosixPath('../ALLDataGross/BlindData/20200925-20-045.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-19-044.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-03-BJ-TB.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-11-036.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-08-033.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-04-ÖG-TB.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-12-037.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-15-040.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-02-AA-DB.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-22-047.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-23-048.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-18-043.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-21-046.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-01-KM-02.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-14-039.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-17-042.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-05-030.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-10-035.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-09-034.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-13-038.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-07-032.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-16-041.dpt'), PosixPath('../ALLDataGross/BlindData/20200925-06-031.dpt')]
# ✅ Loaded 20200925-01-KM-02.dpt with 2 columns
# ✅ Loaded 20200925-02-AA-DB.dpt with 2 columns
# ✅ Loaded 20200925-03-BJ-TB.dpt with 2 columns
# ✅ Loaded 20200925-04-ÖG-TB.dpt with 2 columns
# ✅ Loaded 20200925-05-030.dpt with 2 columns
# ✅ Loaded 20200925-06-031.dpt with 2 columns
# ✅ Loaded 20200925-07-032.dpt with 2 columns
# ✅ Loaded 20200925-08-033.dpt with 2 columns
# ✅ Loaded 20200925-09-034.dpt with 2 columns
# ✅ Loaded 20200925-10-035.dpt with 2 columns
# ✅ Loaded 20200925-11-036.dpt with 2 columns
# ✅ Loaded 20200925-12-037.dpt with 2 columns
# ✅ Loaded 20200925-13-038.dpt with 2 columns
# ✅ Loaded 20200925-14-039.dpt with 2 columns
# ✅ Loaded 20200925-15-040.dpt with 2 columns
# ✅ Loaded 20200925-16-041.dpt with 2 columns
# ✅ Loaded 20200925-17-042.dpt with 2 columns
# ✅ Loaded 20200925-18-043.dpt with 2 columns
# ✅ Loaded 20200925-19-044.dpt with 2 columns
# ✅ Loaded 20200925-20-045.dpt with 2 columns
# ✅ Loaded 20200925-21-046.dpt with 2 columns
# ✅ Loaded 20200925-22-047.dpt with 2 columns
# ✅ Loaded 20200925-23-048.dpt with 2 columns
# Folder exists: True
# Folder contents: [PosixPath('../ALLDataGross/healthyCohort/20180205-16-CW-TB.16.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-22-SR-TB-M1.22.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190606-15-KW-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171123-18-AA-ExD.dpt'), PosixPath('../ALLDataGross/healthyCohort/20180205-01-OL-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190405-05-004.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-16-AL-TB-M1.16.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-01-EL-TB-8y.01.dpt'), PosixPath('../ALLDataGross/healthyCohort/20180802-05-MF-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190405-02-001.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-17-AH-TB-M1.17.dpt'), PosixPath('../ALLDataGross/healthyCohort/Healthy.mat'), PosixPath('../ALLDataGross/healthyCohort/20171109-02-PL-TB-5y.02.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-04-OG-TB-M1.04.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-26-ML-TB-M1.26.dpt'), PosixPath('../ALLDataGross/healthyCohort/20180205-17-MG-TB.17.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190312-12-EF-DB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190606-14-CR-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20180125-22-TS-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-06-TA-TB-M1.06.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190606-08-016.dpt'), PosixPath('../ALLDataGross/healthyCohort/dataLoad20200207h.m'), PosixPath('../ALLDataGross/healthyCohort/20171123-04-KM-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190606-07-015.dpt')]
# DPT files found: [PosixPath('../ALLDataGross/healthyCohort/20180205-16-CW-TB.16.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-22-SR-TB-M1.22.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190606-15-KW-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171123-18-AA-ExD.dpt'), PosixPath('../ALLDataGross/healthyCohort/20180205-01-OL-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190405-05-004.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-16-AL-TB-M1.16.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-01-EL-TB-8y.01.dpt'), PosixPath('../ALLDataGross/healthyCohort/20180802-05-MF-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190405-02-001.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-17-AH-TB-M1.17.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-02-PL-TB-5y.02.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-04-OG-TB-M1.04.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-26-ML-TB-M1.26.dpt'), PosixPath('../ALLDataGross/healthyCohort/20180205-17-MG-TB.17.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190312-12-EF-DB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190606-14-CR-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20180125-22-TS-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171109-06-TA-TB-M1.06.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190606-08-016.dpt'), PosixPath('../ALLDataGross/healthyCohort/20171123-04-KM-TB.dpt'), PosixPath('../ALLDataGross/healthyCohort/20190606-07-015.dpt')]
# ✅ Loaded 20171109-01-EL-TB-8y.01.dpt with 2 columns
# ✅ Loaded 20171109-02-PL-TB-5y.02.dpt with 2 columns
# ✅ Loaded 20171109-04-OG-TB-M1.04.dpt with 2 columns
# ✅ Loaded 20171109-06-TA-TB-M1.06.dpt with 2 columns
# ✅ Loaded 20171109-16-AL-TB-M1.16.dpt with 2 columns
# ✅ Loaded 20171109-17-AH-TB-M1.17.dpt with 2 columns
# ✅ Loaded 20171109-22-SR-TB-M1.22.dpt with 2 columns
# ✅ Loaded 20171109-26-ML-TB-M1.26.dpt with 2 columns
# ✅ Loaded 20171123-04-KM-TB.dpt with 2 columns
# ✅ Loaded 20171123-18-AA-ExD.dpt with 2 columns
# ✅ Loaded 20180125-22-TS-TB.dpt with 2 columns
# ✅ Loaded 20180205-01-OL-TB.dpt with 2 columns
# ✅ Loaded 20180205-16-CW-TB.16.dpt with 2 columns
# ✅ Loaded 20180205-17-MG-TB.17.dpt with 2 columns
# ✅ Loaded 20180802-05-MF-TB.dpt with 2 columns
# ✅ Loaded 20190312-12-EF-DB.dpt with 2 columns
# ✅ Loaded 20190405-02-001.dpt with 2 columns
# ✅ Loaded 20190405-05-004.dpt with 2 columns
# ✅ Loaded 20190606-07-015.dpt with 2 columns
# ✅ Loaded 20190606-08-016.dpt with 2 columns
# ✅ Loaded 20190606-14-CR-TB.dpt with 2 columns
# ✅ Loaded 20190606-15-KW-TB.dpt with 2 columns
# 0 done!
# 1 done!
# 2 done!
# 3 done!
# 4 done!
# 5 done!
# 6 done!
# 7 done!
# 8 done!
# 9 done!
# 10 done!
# 11 done!
# 12 done!
# 13 done!
# 14 done!
# 15 done!
# 16 done!
# 17 done!
# 18 done!
# 19 done!
# 20 done!
# 21 done!
# 22 done!
# 23 done!
# 24 done!
# 25 done!
# 26 done!
# 27 done!
# 28 done!
# 29 done!
# 30 done!
# 31 done!
# 32 done!
# 33 done!
# 34 done!
# 35 done!
# 36 done!
# 37 done!
# 38 done!
# 39 done!
# 40 done!
# 41 done!
# 42 done!
# 43 done!
# 44 done!
# 45 done!
# 46 done!
# 47 done!
# 48 done!
# 49 done!
# 50 done!
# 51 done!
# 52 done!
# 53 done!
# 54 done!
# 55 done!
# 56 done!
# 57 done!
# 58 done!
# 59 done!
# 60 done!
# 61 done!
# 62 done!
# 63 done!
# 64 done!
# 65 done!
# 66 done!
# 67 done!
# 68 done!
# 69 done!
# 70 done!
# 71 done!
# 72 done!
# 73 done!
# baseline corrected!

# %% [markdown]
# ### Create blind dataset and define relevant Spectral Regions

# %%
df_blind = df[df["category"] == "blinddata"]
df = df[df["category"]!= "blinddata"]
df["category"].unique()

SRList = [1005, 530, 1050, 1190, 1203, 1170, 2170]
SRdict = {f"SR_{sr}": (sr-15, sr+15) for sr in SRList}
SRdict
# Out:
# {'SR_1005': (990, 1020),
#  'SR_530': (515, 545),
#  'SR_1050': (1035, 1065),
#  'SR_1190': (1175, 1205),
#  'SR_1203': (1188, 1218),
#  'SR_1170': (1155, 1185),
#  'SR_2170': (2155, 2185)}

# %%
df["class"] = df["infoP"].apply(lambda x: "Healthy" if x in ["M", "F", "H"] else x)

def extract_sr_matrix(df, start, end):
    # Find indices once for the first row
    wn = df.iloc[0]['wavenumber']
    mask = (wn >= start) & (wn <= end)
    return np.stack(df['intensity_baseline_corrected'].apply(lambda x: x[mask]).values)

SR_matrices = {}
for name, (s,e) in SRdict.items():
    SR_matrices[name] = extract_sr_matrix(df, s, e)


print("(rows = patients, cols = spectral points)")
# for k in SR_matrices.keys():
#     print(f"shape of matrix corresponding to {k} : {SR_matrices[k].shape}")
# Out:
# (rows = patients, cols = spectral points)
# /tmp/ipykernel_214102/2916107394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["class"] = df["infoP"].apply(lambda x: "Healthy" if x in ["M", "F", "H"] else x)

# %% [markdown]
# ### WRONG PREPROCESSING

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

os.makedirs("figures", exist_ok=True)

# --- Helper: build a ±15 cm^-1 SR matrix centered at `center` ---
def extract_window_matrix(df, center, half_width=15, intensity_key="intensity_baseline_corrected"):
    wn = df.iloc[0]["wavenumber"]
    mask = (wn >= center - half_width) & (wn <= center + half_width)
    X = np.stack(df[intensity_key].apply(lambda y: y[mask]).values)  # (n_samples, n_points)
    wn_win = wn[mask]
    return wn_win, X

# --- Fit PCA for each SR window (standardized across patients) ---
def fit_sr_pca(X, n_components=3):
    scaler = StandardScaler()
    Xs = scaler.fit_transform(X)
    pca = PCA(n_components=min(n_components, Xs.shape[1]))
    pca.fit(Xs)
    return pca

# Two representative SRs
sr_centers = [1005, 2170]
half_width = 15
K = 3

fig, axes = plt.subplots(len(sr_centers), K, figsize=(12, 5), sharex='row')
if len(sr_centers) == 1:
    axes = np.array([axes])

for r, c0 in enumerate(sr_centers):
    wn_win, X = extract_window_matrix(df, center=c0, half_width=half_width)
    pca = fit_sr_pca(X, n_components=K)

    for k in range(K):
        ax = axes[r, k]
        psi = pca.components_[k]
        evr = pca.explained_variance_ratio_[k]

        ax.plot(wn_win, psi, color="navy", linewidth=1.2)
        ax.axhline(0, color="black", linewidth=0.8, alpha=0.6)
        ax.invert_xaxis()

        ax.set_title(f"SR {c0} | $\\hat{{\\psi}}_{k+1}(t)$ (EVR={evr*100:.1f}%)")
        ax.grid(alpha=0.25, linestyle="--")

        if k == 0:
            ax.set_ylabel("Loading (a.u.)")

    axes[r, 0].set_xlabel("Wavenumber (cm$^{-1}$)")
    axes[r, 1].set_xlabel("Wavenumber (cm$^{-1}$)")
    axes[r, 2].set_xlabel("Wavenumber (cm$^{-1}$)")

plt.tight_layout()
plt.savefig("figures/fpc_modes_srs.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
for name, mat in SR_matrices.items():

    mat = mat - mat.mean(axis=0)
    print("Feature means:", mat.mean(axis=0)[:5])
    print("Feature stds:", mat.std(axis=0)[:5])
# Out:
# Feature means: [ 0.00000000e+00 -1.72728287e-21 -6.37765984e-21 -1.62098854e-20
#  -1.06294331e-21]
# Feature stds: [0.00000000e+00 7.11709131e-05 1.07868311e-04 1.38642678e-04
#  1.35774941e-04]
# Feature means: [-2.31296463e-18 -2.44902138e-18 -8.02734785e-18  3.80958881e-18
#   3.67353207e-18]
# Feature stds: [0.02545721 0.02534455 0.02545154 0.02560145 0.02554995]
# Feature means: [ 2.99324835e-18 -3.60550370e-18 -2.10887952e-18 -3.94564555e-18
#   3.74156044e-18]
# Feature stds: [0.01010649 0.01012294 0.01017744 0.01021149 0.01018975]
# Feature means: [-1.27553197e-20  6.37765984e-20  1.74322702e-19  1.91329795e-20
#   4.67695055e-20]
# Feature stds: [0.00022691 0.00024522 0.00025816 0.00026222 0.00025867]
# Feature means: [-1.27553197e-19 -5.31471653e-20  0.00000000e+00 -1.91329795e-19
#   1.70070929e-20]
# Feature stds: [0.00034831 0.00034922 0.00033425 0.00032358 0.00033863]
# Feature means: [ 1.93987153e-20  3.72030157e-21 -3.72030157e-21 -2.12588661e-21
#   1.06294331e-20]
# Feature stds: [0.0001078  0.00011378 0.00011496 0.00011768 0.00012857]
# Feature means: [ 6.80283716e-20 -2.12588661e-20  1.17986707e-19 -7.65319181e-20
#  -2.12588661e-21]
# Feature stds: [0.00095008 0.00022154 0.00015032 0.00016267 0.00017272]

# %% [markdown]
# ### Apply PCA

# %%
from sklearn.decomposition import PCA

pca_results = {}
numPcs = 4

for name, mat in SR_matrices.items():

    # 1️⃣ Mean centering ONLY
    # mat = mat - mat.mean(axis=0)

    # 2️⃣ PCA
    pca = PCA(n_components=numPcs, svd_solver='full')
    pcs = pca.fit_transform(mat - mat.mean(axis=0))

    pca_results[name] = pcs
    # pca_results[name] = {
    #     "scores": pcs,
    #     "loadings": pca.components_,
    #     "explained_variance": pca.explained_variance_ratio_
    # }
result_df = df[['patient_id','infoP']].copy()
result_df = result_df[result_df['infoP'].isin(["PC", "M", "F", "H", "KC", "BC"])]
result_df["class"] = result_df["infoP"].apply(lambda x: "Healthy" if x in ["M", "F", "H"] else x)
print(len(pca_results[list(pca_results.keys())[0]]))
print(pca_results.keys())
for name, pcs in pca_results.items():
    for n in range(numPcs):
        result_df[f'{name}_PC{n+1}'] = pcs[:,n]

# result_df = result_df[result_df['infoP'].isin(["PC", "M", "F", "H", "KC", "BC"])]
# result_df["class"] = result_df["infoP"].apply(lambda x: "Healthy" if x in ["M", "F", "H"] else x)
result_df["class"].unique()
# Out:
# 51
# dict_keys(['SR_1005', 'SR_530', 'SR_1050', 'SR_1190', 'SR_1203', 'SR_1170', 'SR_2170'])
# array(['Healthy', 'PC', 'BC', 'KC'], dtype=object)

# %%
df["class"].unique()
SRs = SRdict

# %%
pvalue_matrix = []
for name in SRs.keys():
    row = []
    for pc in [f"PC{n+1}" for n in range(numPcs)]:
        h = result_df[result_df['class']=='Healthy'][f'{name}_{pc}']
        c = result_df[result_df['class'].isin(["PC"])][f'{name}_{pc}']
        # print(name, pc, f_oneway(h,c).pvalue)
        pval = f_oneway(h, c).pvalue
        row.append(pval)
    pvalue_matrix.append(row)

# Convert to DataFrame for better visualization
pvalue_df = pd.DataFrame(
    pvalue_matrix,
    index=list(SRs.keys()),  # Row names
    columns=[f"PC{n+1}" for n in range(numPcs)]  # Column names
)


# Create the heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(
    pvalue_df,
    annot=True,           # Show p-values on cells
    fmt=".3e",           # Scientific notation for small p-values
    cmap='viridis_r',    # Reverse viridis (darker = smaller p-value)
    cbar_kws={'label': 'p-value'},
    linewidths=0.5,
    linecolor='gray'
)

plt.title('F-oneway ANOVA p-values: Healthy vs Cancer', fontsize=14, fontweight='bold')
plt.xlabel('Principal Components', fontsize=12)
plt.ylabel('Sample Regions', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
#  1. ANOVA p-value (the input)
#
#   Before this cell, we ran a one-way ANOVA for each (Spectral Region, Principal Component) pair, testing:
#
#   ▎ H₀: The mean PC score is the same across Healthy, PC, BC, KC groups
#
#   The F-statistic is:
#   F = (variance between groups) / (variance within groups)
#     = [Σ nᵢ(ȳᵢ - ȳ)² / (k-1)] / [Σᵢ Σⱼ (yᵢⱼ - ȳᵢ)² / (N-k)]
#   The p-value is then P(F_dist ≥ F_observed) — small p means the groups differ significantly on that PC in that SR.
#
#   ---
#   2. The multiple testing problem
#
#   we have 7 SRs × 4 PCs = 28 separate ANOVA tests. If each uses α=0.05, by chance alone one would expect ~1.4 false positives even if nothing is truly significant. Running many tests inflates the
#   false positive rate.
#   At α=0.05, each individual test has a 5% chance of a false positive even when H₀ is true.
#
#   If we run 28 independent tests, each with a 5% false positive rate:
#
#   E[false positives] = 28 × 0.05 = 1.4
#
#   Bonferroni is the strictest fix — divide α by number of tests:
#   adjusted threshold = 0.05 / 28 ≈ 0.0018
#   Only reject H₀ if raw p < 0.0018. Very conservative — reduces false positives but misses real effects.
#
#   Benjamini-Hochberg (FDR) is less strict — it controls the expected proportion of false discoveries among rejections (not just the chance of any false positive):
#   Sort p-values: p₍₁₎ ≤ p₍₂₎ ≤ ... ≤ p₍₂₈₎
#   Reject all H₀ up to largest k where p₍ₖ₎ ≤ (k/28) × 0.05
#   More powerful than Bonferroni — finds more real effects at the cost of allowing ~5% of significant results to be false.
#
#   ---
#   3. Intuitively
#
#   we're asking: "Which spectral regions carry discriminative information between healthy and cancer patients, as captured by PCA?"
#
#   - A significant (SR, PC) pair means: the cancer groups separate from healthy on that PC score, in that wavenumber region
#   - Bonferroni significant → very strong evidence
#   - FDR-only significant → suggestive, likely real but weaker evidence
#   - The heatmap + ✱ stars let us visually see where in the spectrum the groups differ
#
#   ---
#   4. For this project
#
#   This cell bridges our PCA analysis and our SVM classification:
#
#   - It tells us which SRs are informative — SRs with significant (SR, PC) pairs are the ones where healthy vs cancer spectra differ
#   - This justifies why the SVM (in the next stage) uses PC scores from specific SRs as features rather than raw spectra
#   - If SR3-PC1 is significant, it means the first principal component of that spectral window genuinely captures cancer-related biochemical variation — giving your SVM a meaningful feature to
#   classify on

# %%
                
from statsmodels.stats.multitest import multipletests
                                            
# ── Flatten p-values, apply corrections ───────────────────────────────────
pvals_flat = pvalue_df.values.flatten()   # row-major: SR1-PC1, SR1-PC2, ..., SR7-PC4
                                                                                                                                                                                                
# Bonferroni                                                                                                                                                                                    
reject_bf, pvals_bf, _, _ = multipletests(pvals_flat, alpha=0.05, method='bonferroni')                                                                                                          
                                                                                                                                                                                                
# Benjamini-Hochberg (FDR)              
reject_fdr, pvals_fdr, _, _ = multipletests(pvals_flat, alpha=0.05, method='fdr_bh')                                                                                                            
                                                                                                                                                                                                
# Reshape back to (n_SRs, numPcs)       
shape = pvalue_df.shape                                                                                                                                                                         
bf_df  = pd.DataFrame(pvals_bf.reshape(shape),  index=pvalue_df.index, columns=pvalue_df.columns)                                                                                               
fdr_df = pd.DataFrame(pvals_fdr.reshape(shape), index=pvalue_df.index, columns=pvalue_df.columns)
                                                                                                                                                                                                
reject_bf_df  = pd.DataFrame(reject_bf.reshape(shape),  index=pvalue_df.index, columns=pvalue_df.columns)                                                                                       
reject_fdr_df = pd.DataFrame(reject_fdr.reshape(shape), index=pvalue_df.index, columns=pvalue_df.columns)                                                                                       
                                                                                                                                                                                                
# ── Print significant SR-PCs ───────────────────────────────────────────────                                                                                                                   
print("Significant after Bonferroni (α=0.05):")                                                                                                                                                 
for sr in pvalue_df.index:                                                                                                                                                                      
    for pc in pvalue_df.columns:                                                                                                                                                                
        if reject_bf_df.loc[sr, pc]:                                                                                                                                                            
            print(f"  {sr} {pc}  raw p={pvalue_df.loc[sr,pc]:.3e}  adj p={bf_df.loc[sr,pc]:.3e}")                                                                                               
                                                                                                                                                                                                
print("\nSignificant after FDR (Benjamini-Hochberg, α=0.05):")
for sr in pvalue_df.index:                                                                                                                                                                      
    for pc in pvalue_df.columns:                                                                                                                                                                
        if reject_fdr_df.loc[sr, pc]:                                                                                                                                                           
            print(f"  {sr} {pc}  raw p={pvalue_df.loc[sr,pc]:.3e}  adj p={fdr_df.loc[sr,pc]:.3e}")                                                                                              
                                                                                                                                                                                                
# ── Side-by-side heatmaps: Bonferroni vs FDR ──────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
                                                                                                                                                                                                
for ax, adj_df, reject_df, title in zip(                                                                                                                                                        
    axes,                                                                                                                                                                                       
    [bf_df, fdr_df],                                                                                                                                                                            
    [reject_bf_df, reject_fdr_df],                                                                                                                                                              
    ["Bonferroni-adjusted p-values", "FDR-adjusted p-values (BH)"]                                                                                                                              
):                                                                                                                                                                                              
    sns.heatmap(                        
        adj_df,
        annot=True, fmt=".3e",                                                                                                                                                                  
        cmap='viridis_r',                   
        cbar_kws={'label': 'adjusted p-value'},                                                                                                                                                 
        linewidths=0.5, linecolor='gray',
        ax=ax                                                                                                                                                                                   
    )                                   
                                                                                                                                                                                                
    # Mark significant cells with a star                                                                                                                                                        
    for i, sr in enumerate(adj_df.index):
        for j, pc in enumerate(adj_df.columns):                                                                                                                                                 
            if reject_df.loc[sr, pc]:   
                ax.text(j + 0.5, i + 0.75, "✱",
                        ha='center', va='center',                                                                                                                                               
                        fontsize=14, color='white', fontweight='bold')
                                                                                                                                                                                                
    ax.set_title(title, fontsize=13, fontweight='bold')                                                                                                                                         
    ax.set_xlabel('Principal Components', fontsize=11)
    ax.set_ylabel('Spectral Regions', fontsize=11)                                                                                                                                              
                                        
plt.suptitle('Multiple-testing corrected ANOVA: Healthy vs Cancer',                                                                                                                             
            fontsize=14, fontweight='bold', y=1.02)                                                                                                                                            
plt.tight_layout()                          
plt.savefig("figures/anova_corrected_pvalues.png", dpi=300, bbox_inches="tight")                                                                                                                
plt.show()
# Out:
# Significant after Bonferroni (α=0.05):
#   SR_1005 PC1  raw p=1.613e-03  adj p=4.517e-02
#   SR_530 PC3  raw p=4.641e-04  adj p=1.300e-02
#   SR_2170 PC3  raw p=1.398e-03  adj p=3.916e-02
#
# Significant after FDR (Benjamini-Hochberg, α=0.05):
#   SR_1005 PC1  raw p=1.613e-03  adj p=1.506e-02
#   SR_530 PC3  raw p=4.641e-04  adj p=1.300e-02
#   SR_2170 PC3  raw p=1.398e-03  adj p=1.506e-02

# %%
result_df["class"].value_counts()
# Out:
# class
# Healthy    26
# PC         17
# BC          5
# KC          3
# Name: count, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

df = df[df['infoP'].isin(["PC", "M", "F", "H", "KC", "BC"])]
df["class"] = df["infoP"].apply(lambda x: "H" if x in ["M", "F", "H"] else x)
print(df["class"].unique())

# filter groups
healthy = df[df["class"] == "H"]
pca = df[df["class"] == "PC"]

x_lo,x_hi = 500, 570
y_lo, y_hi = -0.05, 0

# stack spectra
original = np.vstack(healthy["intensity_baseline_corrected"].to_numpy())
thirdorder = np.vstack(pca["intensity_baseline_corrected"].to_numpy())

# compute mean and std
H_mean = np.mean(original, axis=0)
H_std = np.std(original, axis=0)

C_mean = np.mean(thirdorder, axis=0)
C_std = np.std(thirdorder, axis=0)

# shared wavenumber axis
wn = df["wavenumber"].iloc[0]  # assume same for all

plt.figure(figsize=(10,6))

plt.plot(wn, H_mean, color="red", label="Healthy")
plt.fill_between(wn, H_mean-H_std, H_mean+H_std, alpha=0.08, color="red")

plt.plot(wn, C_mean, color="blue", label="PCa")
plt.fill_between(wn, C_mean-C_std, C_mean+C_std, alpha=0.06, color="blue")

plt.xlim(x_lo, x_hi)
plt.ylim(y_lo, y_hi)
plt.xlabel("Wavenumbers (cm$^{-1}$)")
plt.ylabel("Absorbance")
plt.legend()
plt.title(f"Mean Breath Spectra around {(x_hi + x_lo)/2} cm$^{-1}$")
plt.show()
# Out:
# ['H' 'PC' 'BC' 'KC']

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 73
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patient_id   51 non-null     object
#  1   infoP        51 non-null     object
#  2   class        51 non-null     object
#  3   SR_1005_PC1  51 non-null     float64
#  4   SR_1005_PC2  51 non-null     float64
#  5   SR_1005_PC3  51 non-null     float64
#  6   SR_1005_PC4  51 non-null     float64
#  7   SR_530_PC1   51 non-null     float64
#  8   SR_530_PC2   51 non-null     float64
#  9   SR_530_PC3   51 non-null     float64
#  10  SR_530_PC4   51 non-null     float64
#  11  SR_1050_PC1  51 non-null     float64
#  12  SR_1050_PC2  51 non-null     float64
#  13  SR_1050_PC3  51 non-null     float64
#  14  SR_1050_PC4  51 non-null     float64
#  15  SR_1190_PC1  51 non-null     float64
#  16  SR_1190_PC2  51 non-null     float64
#  17  SR_1190_PC3  51 non-null     float64
#  18  SR_1190_PC4  51 non-null     float64
#  19  SR_1203_PC1  51 non-null     float64
#  20  SR_1203_PC2  51 non-null     float64
#  21  SR_1203_PC3  51 non-null     float64
#  22  SR_1203_PC4  51 non-null     float64
#  23  SR_1170_PC1  51 non-null     float64
#  24  SR_1170_PC2  51 non-null     float64
#  25  SR_1170_PC3  51 non-null     float64
#  26  SR_1170_PC4  51 non-null     float64
#  27  SR_2170_PC1  51 non-null     float64
#  28  SR_2170_PC2  51 non-null     float64
#  29  SR_2170_PC3  51 non-null     float64
#  30  SR_2170_PC4  51 non-null     float64
# dtypes: float64(28), object(3)
# memory usage: 12.8+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

def draw_cov_ellipse(x, y, ax, color):
    cov = np.cov(x, y)
    vals, vecs = np.linalg.eigh(cov)
    order = vals.argsort()[::-1]
    vals, vecs = vals[order], vecs[:, order]

    theta = np.degrees(np.arctan2(*vecs[:, 0][::-1]))
    width, height = 2 * np.sqrt(vals)

    ellipse = Ellipse(
        (x.mean(), y.mean()),
        width, height,
        angle=theta,
        edgecolor=color,
        facecolor='none',
        linewidth=2
    )
    ax.add_patch(ellipse)

# %%
fig, ax = plt.subplots(figsize=(8,6))

for g, color, label in [(['Healthy'],'blue','Healthy'), (['PC'],'red','PC'), (['KC', 'BC'], 'black', 'KC+BC')]:
    sub = result_df[result_df['class'].isin(g)]
    print(sub.info())
    x = sub['SR_530_PC1'].values
    y = sub['SR_530_PC3'].values

    ax.scatter(x, y, color=color, alpha=0.7, label=label)
    draw_cov_ellipse(x, y, ax, color)
    ax.scatter(x.mean(), y.mean(), marker='x', color=color, s=80)

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.legend()
ax.set_title('SR 1170 cm$^{-1}$: PC2 vs PC1')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 0 to 73
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patient_id   26 non-null     object
#  1   infoP        26 non-null     object
#  2   class        26 non-null     object
#  3   SR_1005_PC1  26 non-null     float64
#  4   SR_1005_PC2  26 non-null     float64
#  5   SR_1005_PC3  26 non-null     float64
#  6   SR_1005_PC4  26 non-null     float64
#  7   SR_530_PC1   26 non-null     float64
#  8   SR_530_PC2   26 non-null     float64
#  9   SR_530_PC3   26 non-null     float64
#  10  SR_530_PC4   26 non-null     float64
#  11  SR_1050_PC1  26 non-null     float64
#  12  SR_1050_PC2  26 non-null     float64
#  13  SR_1050_PC3  26 non-null     float64
#  14  SR_1050_PC4  26 non-null     float64
#  15  SR_1190_PC1  26 non-null     float64
#  16  SR_1190_PC2  26 non-null     float64
#  17  SR_1190_PC3  26 non-null     float64
#  18  SR_1190_PC4  26 non-null     float64
#  19  SR_1203_PC1  26 non-null     float64
#  20  SR_1203_PC2  26 non-null     float64
#  21  SR_1203_PC3  26 non-null     float64
#  22  SR_1203_PC4  26 non-null     float64
#  23  SR_1170_PC1  26 non-null     float64
#  24  SR_1170_PC2  26 non-null     float64
#  25  SR_1170_PC3  26 non-null     float64
#  26  SR_1170_PC4  26 non-null     float64
#  27  SR_2170_PC1  26 non-null     float64
#  28  SR_2170_PC2  26 non-null     float64
#  29  SR_2170_PC3  26 non-null     float64
#  30  SR_2170_PC4  26 non-null     float64
# dtypes: float64(28), object(3)
# memory usage: 6.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1 to 28
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patient_id   17 non-null     object
#  1   infoP        17 non-null     object
#  2   class        17 non-null     object
#  3   SR_1005_PC1  17 non-null     float64
#  4   SR_1005_PC2  17 non-null     float64
#  5   SR_1005_PC3  17 non-null     float64
#  6   SR_1005_PC4  17 non-null     float64
#  7   SR_530_PC1   17 non-null     float64
#  8   SR_530_PC2   17 non-null     float64
#  9   SR_530_PC3   17 non-null     float64
#  10  SR_530_PC4   17 non-null     float64
#  11  SR_1050_PC1  17 non-null     float64
#  12  SR_1050_PC2  17 non-null     float64
#  13  SR_1050_PC3  17 non-null     float64
#  14  SR_1050_PC4  17 non-null     float64
#  15  SR_1190_PC1  17 non-null     float64
#  16  SR_1190_PC2  17 non-null     float64
#  17  SR_1190_PC3  17 non-null     float64
#  18  SR_1190_PC4  17 non-null     float64
#  19  SR_1203_PC1  17 non-null     float64
#  20  SR_1203_PC2  17 non-null     float64
#  21  SR_1203_PC3  17 non-null     float64
#  22  SR_1203_PC4  17 non-null     float64
#  23  SR_1170_PC1  17 non-null     float64
#  24  SR_1170_PC2  17 non-null     float64
#  25  SR_1170_PC3  17 non-null     float64
#  26  SR_1170_PC4  17 non-null     float64
#  27  SR_2170_PC1  17 non-null     float64
#  28  SR_2170_PC2  17 non-null     float64
#  29  SR_2170_PC3  17 non-null     float64
#  30  SR_2170_PC4  17 non-null     float64
# dtypes: float64(28), object(3)
# memory usage: 4.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 5 to 25
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patient_id   8 non-null      object
#  1   infoP        8 non-null      object
#  2   class        8 non-null      object
#  3   SR_1005_PC1  8 non-null      float64
#  4   SR_1005_PC2  8 non-null      float64
#  5   SR_1005_PC3  8 non-null      float64
#  6   SR_1005_PC4  8 non-null      float64
#  7   SR_530_PC1   8 non-null      float64
#  8   SR_530_PC2   8 non-null      float64
#  9   SR_530_PC3   8 non-null      float64
#  10  SR_530_PC4   8 non-null      float64
#  11  SR_1050_PC1  8 non-null      float64
#  12  SR_1050_PC2  8 non-null      float64
#  13  SR_1050_PC3  8 non-null      float64
#  14  SR_1050_PC4  8 non-null      float64
#  15  SR_1190_PC1  8 non-null      float64
#  16  SR_1190_PC2  8 non-null      float64
#  17  SR_1190_PC3  8 non-null      float64
#  18  SR_1190_PC4  8 non-null      float64
#  19  SR_1203_PC1  8 non-null      float64
#  20  SR_1203_PC2  8 non-null      float64
#  21  SR_1203_PC3  8 non-null      float64
#  22  SR_1203_PC4  8 non-null      float64
#  23  SR_1170_PC1  8 non-null      float64
#  24  SR_1170_PC2  8 non-null      float64
#  25  SR_1170_PC3  8 non-null      float64
#  26  SR_1170_PC4  8 non-null      float64
#  27  SR_2170_PC1  8 non-null      float64
#  28  SR_2170_PC2  8 non-null      float64
#  29  SR_2170_PC3  8 non-null      float64
#  30  SR_2170_PC4  8 non-null      float64
# dtypes: float64(28), object(3)
# memory usage: 2.0+ KB
# None

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 73
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patient_id   51 non-null     object
#  1   infoP        51 non-null     object
#  2   class        51 non-null     object
#  3   SR_1005_PC1  51 non-null     float64
#  4   SR_1005_PC2  51 non-null     float64
#  5   SR_1005_PC3  51 non-null     float64
#  6   SR_1005_PC4  51 non-null     float64
#  7   SR_530_PC1   51 non-null     float64
#  8   SR_530_PC2   51 non-null     float64
#  9   SR_530_PC3   51 non-null     float64
#  10  SR_530_PC4   51 non-null     float64
#  11  SR_1050_PC1  51 non-null     float64
#  12  SR_1050_PC2  51 non-null     float64
#  13  SR_1050_PC3  51 non-null     float64
#  14  SR_1050_PC4  51 non-null     float64
#  15  SR_1190_PC1  51 non-null     float64
#  16  SR_1190_PC2  51 non-null     float64
#  17  SR_1190_PC3  51 non-null     float64
#  18  SR_1190_PC4  51 non-null     float64
#  19  SR_1203_PC1  51 non-null     float64
#  20  SR_1203_PC2  51 non-null     float64
#  21  SR_1203_PC3  51 non-null     float64
#  22  SR_1203_PC4  51 non-null     float64
#  23  SR_1170_PC1  51 non-null     float64
#  24  SR_1170_PC2  51 non-null     float64
#  25  SR_1170_PC3  51 non-null     float64
#  26  SR_1170_PC4  51 non-null     float64
#  27  SR_2170_PC1  51 non-null     float64
#  28  SR_2170_PC2  51 non-null     float64
#  29  SR_2170_PC3  51 non-null     float64
#  30  SR_2170_PC4  51 non-null     float64
# dtypes: float64(28), object(3)
# memory usage: 12.8+ KB

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# Function to create 3D ellipsoid mesh
def get_ellipsoid_mesh(x, y, z, n_std=1.0, n_points=20):
    """
    x, y, z: arrays of points
    n_std: number of standard deviations for the ellipsoid
    n_points: mesh resolution
    """
    # Compute centroid and covariance
    data = np.vstack([x, y, z])
    cov = np.cov(data)
    mean = np.mean(data, axis=1)

    # Eigen decomposition (axes of ellipsoid)
    U, s, rotation = np.linalg.svd(cov)
    radii = n_std * np.sqrt(s)

    # Parametric angles
    u = np.linspace(0, 2 * np.pi, n_points)
    v = np.linspace(0, np.pi, n_points)
    u, v = np.meshgrid(u, v)

    # Parametric ellipsoid (unit sphere scaled by radii)
    X = radii[0] * np.cos(u) * np.sin(v)
    Y = radii[1] * np.sin(u) * np.sin(v)
    Z = radii[2] * np.cos(v)

    # Rotate and translate
    for i in range(len(X)):
        for j in range(len(X)):
            vec = rotation @ np.array([X[i, j], Y[i, j], Z[i, j]])
            X[i, j], Y[i, j], Z[i, j] = vec + mean

    return X, Y, Z

# Define groups
groups = [
    (['Healthy'], 'blue', 'Healthy'),
    (['PC'], 'red', 'PC'),
    (['KC', 'BC'], 'black', 'KC+BC')
]

fig = go.Figure()

for g, color, label in groups:
    sub = result_df[result_df['class'].isin(g)]
    
    x = sub['SR_1050_PC1'].values
    y = sub['SR_1050_PC2'].values
    z = sub['SR_1050_PC3'].values

    # Scatter all points
    fig.add_trace(go.Scatter3d(
        x=x, y=y, z=z,
        mode='markers',
        marker=dict(size=5, color=color, opacity=0.7),
        name=label,
        text=sub['patient_id'],
        hovertemplate='Patient: %{text}<br>PC1: %{x:.2f}<br>PC2: %{y:.2f}<br>PC3: %{z:.2f}<extra></extra>'
    ))

    # Scatter centroid
    fig.add_trace(go.Scatter3d(
        x=[x.mean()], y=[y.mean()], z=[z.mean()],
        mode='markers',
        marker=dict(size=10, color=color, symbol='x'),
        name=f'{label} centroid'
    ))

    # Ellipsoid mesh (1 std)
    Xs, Ys, Zs = get_ellipsoid_mesh(x, y, z, n_std=1)
    fig.add_trace(go.Surface(
        x=Xs, y=Ys, z=Zs,
        showscale=False,
        opacity=0.2,
        colorscale=[[0, color], [1, color]],
        name=f'{label} ellipsoid',
        hoverinfo='skip'
    ))

# Layout
fig.update_layout(
    title='SR 1170 cm$^{-1}$: PC1 vs PC2 vs PC3 with ellipsoids',
    scene=dict(
        xaxis_title='PC1',
        yaxis_title='PC2',
        zaxis_title='PC3'
    ),
    legend=dict(itemsizing='constant')
)

# Show in browser (best for VS Code)
import plotly.io as pio
pio.renderers.default = "browser"

fig.show()

# %%
# %matplotlib widget  # optional for matplotlib plots
import plotly.io as pio
pio.renderers.default = "notebook_connected"

pio.renderers.default = "browser"


import pandas as pd
import plotly.graph_objects as go

# Define groups
groups = [
    (['Healthy'], 'blue', 'Healthy'),
    (['PC'], 'red', 'PC'),
    (['KC', 'BC'], 'black', 'KC+BC')
]

fig = go.Figure()

for g, color, label in groups:
    sub = result_df[result_df['class'].isin(g)]
    
    # Scatter all points
    fig.add_trace(go.Scatter3d(
        x=sub['SR_1170_PC1'],
        y=sub['SR_1170_PC2'],
        z=sub['SR_1170_PC3'],
        mode='markers',
        marker=dict(size=5, color=color, opacity=0.7),
        name=label,
        text=sub['patient_id'],  # hover info
        hovertemplate='Patient: %{text}<br>PC1: %{x:.2f}<br>PC2: %{y:.2f}<br>PC3: %{z:.2f}<extra></extra>'
    ))
    
    # Scatter centroid
    fig.add_trace(go.Scatter3d(
        x=[sub['SR_1170_PC1'].mean()],
        y=[sub['SR_1170_PC2'].mean()],
        z=[sub['SR_1170_PC3'].mean()],
        mode='markers',
        marker=dict(size=10, color=color, symbol='x'),
        name=f'{label} centroid'
    ))

# Layout
fig.update_layout(
    title='SR 1170 cm$^{-1}$: PC1 vs PC2 vs PC3',
    scene=dict(
        xaxis_title='PC1',
        yaxis_title='PC2',
        zaxis_title='PC3'
    ),
    legend=dict(itemsizing='constant')
)

fig.show()

# %%
import seaborn as sns
result_df['y_binary'] = result_df['class'].apply(
    lambda x: "H" if x == "Healthy" else "C"
)
SRlist = [1005, 530, 1050, 1190, 1203, 1170, 2170]

# SRList = []
for y in SRlist:
    plt.figure(figsize=(4,4))
    sns.boxplot(
        x='y_binary',
        y=f'SR_{y}_PC1',
        data=result_df
    )
    plt.title(F'SR {y} : PC1 scores')
    plt.xlabel('Group')
    plt.ylabel('PC1')
    plt.show()

# %%
def extract_sr(df, wn_min, wn_max):
    X = []
    wns = None

    for _, row in df.iterrows():
        wn = row['wavenumber']
        inten = row['intensity_baseline_corrected']

        mask = (wn >= wn_min) & (wn <= wn_max)
        X.append(inten[mask])

        if wns is None:
            wns = wn[mask]

    return np.vstack(X), wns

# %%
X_sr1190, wn_sr1190 = extract_sr(df, 1170, 1210)
X_sr1190.shape
# Out:
# (51, 166)

# %%
labels = df['class'].astype(str).values  # '0' healthy, '1' cancer

# %%
import matplotlib.pyplot as plt

X_h = X_sr1190[labels == 'H']
X_c = X_sr1190[labels == 'PC']

mean_h, std_h = X_h.mean(axis=0), X_h.std(axis=0)
mean_c, std_c = X_c.mean(axis=0), X_c.std(axis=0)

plt.figure(figsize=(6,4))
plt.plot(wn_sr1190, mean_h, label='Healthy', color='green')
plt.fill_between(wn_sr1190, mean_h-std_h, mean_h+std_h,
                 color='green', alpha=0.3)

plt.plot(wn_sr1190, mean_c, label='Cancer', color='red')
plt.fill_between(wn_sr1190, mean_c-std_c, mean_c+std_c,
                 color='red', alpha=0.3)

plt.xlabel('Wavenumber (cm$^{-1}$)')
plt.ylabel('Absorbance (a.u.)')
plt.ylim(-0.001, 0.0015)
plt.xlim(1180, 1200)
plt.title('SR centered at 1190 cm$^{-1}$')
plt.legend()
plt.show()

# %%
from sklearn.decomposition import PCA

X_centered = X_sr1190 - X_sr1190.mean(axis=0)

pca = PCA(n_components=4)
scores = pca.fit_transform(X_centered)

plt.figure(figsize=(6,3))
plt.plot(wn_sr1190, pca.components_[0])
plt.xlabel('Wavenumber (cm$^{-1}$)')
plt.ylabel('Loading')
plt.title('SR 1190 – PC1 loading')
plt.show()

# %%
np.corrcoef(scores[:,0], result_df['SR_1190_PC1'])[0,1]
# Out:
# np.float64(0.9992276364849824)

# %% [markdown]
# ## Binary Classification

# %%
df_to_use = result_df[result_df["class"].isin(["Healthy", "PC"])]

df_to_use['y_binary'] = df_to_use['class'].apply(
    lambda x: 0 if x == "Healthy" else 1
)
# Out:
# /tmp/ipykernel_214102/2966948202.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sklearn.svm import SVC
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

def svm_loocv_decision_plot_weighted_multi(df, pcs, c=1, y_col="y_binary"):
    X = df[pcs].values
    y = df[y_col].values

    svm = SVC(kernel="linear", C=c, class_weight="balanced")
    # svm = SVC(kernel="linear", C=c)

    loo = LeaveOneOut()

    decisions = []
    true_labels = []

    for train, test in loo.split(X):
        svm.fit(X[train], y[train])
        decisions.append(svm.decision_function(X[test])[0])
        true_labels.append(y[test][0])

    decisions = np.array(decisions)
    true_labels = np.array(true_labels)

    # Auto-flip if SVM chose the opposite orientation
    if decisions[true_labels == 0].mean() > decisions[true_labels == 1].mean():
        decisions = -decisions

    # Compute predicted labels
    y_pred = (decisions > 0).astype(int)

    # Confusion matrix and metrics
    cm = confusion_matrix(true_labels, y_pred)
    tn, fp, fn, tp = cm.ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    accuracy = (tp + tn) / len(true_labels)

    # Mean decision values per class
    mean_healthy = decisions[true_labels == 0].mean()
    mean_cancer = decisions[true_labels == 1].mean()

    metrics = {
        "confusion_matrix": cm,
        "sensitivity": sensitivity,
        "specificity": specificity,
        "accuracy": accuracy,
        "balanced_accuracy": (sensitivity+specificity)/2,
        "mean_decision_healthy": mean_healthy,
        "mean_decision_cancer": mean_cancer,
        "y_pred": y_pred,
        "decisions": decisions,
        "true_labels": true_labels
    }

    return metrics

def plot_decision_values(decisions, labels):
    plt.figure(figsize=(6,4))
    for i, (d, l) in enumerate(zip(decisions, labels)):
        color = "red" if l == 1 else "blue"
        plt.scatter(i, d, color=color)
    plt.axhline(0, linestyle="--", color="black")
    plt.axhspan(-0.2, 0.2, color="gray", alpha=0.3)
    plt.ylabel("SVM decision value")
    plt.xlabel("Sample index")
    plt.title("LOOCV SVM decision values")
    plt.show()

# %%
num = range(len(SRlist))
# pcs_to_use = [f"SR_{SRlist[n-1]}_PC{1}" for n in num] + ["SR_1050_PC4"]
pcs_to_use = ['SR_2170_PC1','SR_1170_PC1', 'SR_1190_PC1', 'SR_1050_PC1', 'SR_1203_PC1', 'SR_1005_PC1', 'SR_530_PC1'] + ['SR_1050_PC4']
# pcs_to_use = ['SR_2170_PC1']

# pcs_to_use += [f"SR_{SRlist[n-1]}_PC{2}" for n in num]
# pcs_to_use += [f"SR_{SRlist[n-1]}_PC{3}" for n in num]
# pcs_to_use += [f"SR_{SRlist[n-1]}_PC{4}" for n in num]


print(pcs_to_use)
metrics = svm_loocv_decision_plot_weighted_multi(df_to_use, pcs_to_use, c= 0.1)

print("Confusion matrix:\n", metrics["confusion_matrix"])
print(f"Sensitivity: {metrics['sensitivity']:.2f}")
print(f"Specificity: {metrics['specificity']:.2f}")
print(f"Balanced Accuracy: {metrics['balanced_accuracy']:.2f}")
print(f"Accuracy: {metrics['accuracy']:.2f}")
print(f"Mean decision (Healthy): {metrics['mean_decision_healthy']:.2f}")
print(f"Mean decision (Cancer): {metrics['mean_decision_cancer']:.2f}")

plot_decision_values(metrics["decisions"], metrics["true_labels"])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define 4 SR/PC sets for the plots
SR_pc_sets = {
    "SR_2170_PC1": ["SR_2170_PC1"],
    "SR_1050_PC4": ["SR_1050_PC4"],
    "All_PC1s": ['SR_2170_PC1', 'SR_1170_PC1', 'SR_1190_PC1', 'SR_1050_PC1', 
                 'SR_1203_PC1', 'SR_1005_PC1', 'SR_530_PC1'],
    "All_PC1s_plus_1050_PC4": ['SR_2170_PC1', 'SR_1170_PC1', 'SR_1190_PC1', 'SR_1050_PC1',
                                'SR_1203_PC1', 'SR_1005_PC1', 'SR_530_PC1', 'SR_1050_PC4']
}

# Range of C values to test
C_values = [0.001, 0.002, 0.003, 0.004, 0.010, 0.1, 0.5, 1, 2, 5, 10, 50, 100]
# C_values = np.arange(0.001, 100, 0.1)
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()  # easier indexing

for i, (label, pcs_to_use) in enumerate(SR_pc_sets.items()):
    bal_acc_list = []
    for C in C_values:
        metrics = svm_loocv_decision_plot_weighted_multi(
            df_to_use,   # your dataframe
            pcs_to_use, 
            c=C
        )
        bal_acc_list.append(metrics["balanced_accuracy"])
    
    bal_acc_array = np.array(bal_acc_list)
    
    ax = axes[i]
    ax.plot(C_values, bal_acc_array, marker='o', linestyle='-', color='tab:blue')
    ax.set_xscale('log')
    ax.set_xlabel('C (log scale)')
    ax.set_ylabel('LOOCV Balanced Accuracy')
    ax.set_title(label)
    ax.grid(True, which='both', ls='--', alpha=0.5)
    ax.axvline(1, color='red', linestyle='--', label='Chosen C=1')
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Cohen’s d answers the right question:
#
# “Is the disease effect large relative to biological variability?”
#
# Not:
#
# “Can I classify every individual perfectly?”

# %%
import numpy as np

def cohens_d(x0, x1):
    n0, n1 = len(x0), len(x1)
    mu0, mu1 = np.mean(x0), np.mean(x1)
    s0, s1 = np.std(x0, ddof=1), np.std(x1, ddof=1)

    sp = np.sqrt(((n0 - 1)*s0**2 + (n1 - 1)*s1**2) / (n0 + n1 - 2))
    d = (mu1 - mu0) / sp
    return d

# pcs_to_use = "SR_1190_PC1"
for sr in SRlist:
        for n in [1,2,3,4]:
            pc = f"SR_{sr}_PC{n}"
            x_healthy = df_to_use[df_to_use.y_binary == 0][pc].values
            x_cancer  = df_to_use[df_to_use.y_binary == 1][pc].values
            
            d = cohens_d(x_healthy, x_cancer)
            print(f"Cohen's d for {pc}: {d:.3f}")
        print("                                       ")
# Out:
# Cohen's d for SR_1005_PC1: 1.053
# Cohen's d for SR_1005_PC2: -0.176
# Cohen's d for SR_1005_PC3: 0.302
# Cohen's d for SR_1005_PC4: -0.488
#
# Cohen's d for SR_530_PC1: -0.598
# Cohen's d for SR_530_PC2: 0.163
# Cohen's d for SR_530_PC3: -1.187
# Cohen's d for SR_530_PC4: -0.443
#
# Cohen's d for SR_1050_PC1: -0.547
# Cohen's d for SR_1050_PC2: -0.637
# Cohen's d for SR_1050_PC3: -0.243
# Cohen's d for SR_1050_PC4: -0.849
#
# Cohen's d for SR_1190_PC1: 0.785
# Cohen's d for SR_1190_PC2: 0.034
# Cohen's d for SR_1190_PC3: -0.037
# Cohen's d for SR_1190_PC4: -0.027
#
# Cohen's d for SR_1203_PC1: 0.830
# Cohen's d for SR_1203_PC2: 0.061
# Cohen's d for SR_1203_PC3: 0.025
# Cohen's d for SR_1203_PC4: -0.455
#
# Cohen's d for SR_1170_PC1: 0.646
# Cohen's d for SR_1170_PC2: -0.601
# Cohen's d for SR_1170_PC3: 0.031
# Cohen's d for SR_1170_PC4: -0.335
#
# Cohen's d for SR_2170_PC1: -0.012
# Cohen's d for SR_2170_PC2: 0.321
# Cohen's d for SR_2170_PC3: 1.069
# Cohen's d for SR_2170_PC4: -0.273

# %%
from sklearn.svm import SVC
from sklearn.model_selection import LeaveOneOut

def loocv_accuracy(X, y, C=1, balanced=True):
    svm = SVC(
        kernel="linear",
        C=C,
        class_weight="balanced" if balanced else None
    )
    loo = LeaveOneOut()

    correct = 0
    for train, test in loo.split(X):
        svm.fit(X[train], y[train])
        pred = svm.predict(X[test])[0]
        correct += (pred == y[test][0])

    return correct / len(y)

pcs = []
for sr in SRlist:
        for n in [1,2,3]:
            pcs.append(f"SR_{sr}_PC{n}")
X = df_to_use[pcs].values
y = df_to_use.y_binary.values

real_acc = loocv_accuracy(X, y)

n_perm = 1000
perm_accs = []

for _ in range(n_perm):
    y_perm = np.random.permutation(y)
    acc = loocv_accuracy(X, y_perm)
    perm_accs.append(acc)

perm_accs = np.array(perm_accs)
p_value = np.mean(perm_accs >= real_acc)

print(f"Real accuracy: {real_acc:.3f}")
print(f"Permutation p-value: {p_value:.4f}")
print(np.mean(perm_accs))

# %%
np.histogram_bin_edges(perm_accs)

# %%
import numpy as np
from matplotlib.patches import Ellipse
import matplotlib.pyplot as plt

def confidence_ellipse(x, y, ax, n_std=2.0, **kwargs):
    cov = np.cov(x, y)
    vals, vecs = np.linalg.eigh(cov)
    order = vals.argsort()[::-1]
    vals, vecs = vals[order], vecs[:, order]

    theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))
    width, height = 2 * n_std * np.sqrt(vals)

    ellipse = Ellipse(
        xy=(np.mean(x), np.mean(y)),
        width=width,
        height=height,
        angle=theta,
        **kwargs
    )
    ax.add_patch(ellipse)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

# ===== 1. Prepare data =====
X = SR_matrices["SR_1005"]
Xc = X - X.mean(axis=0)

pca = PCA(n_components=4)
scores = pca.fit_transform(Xc)
loadings = pca.components_

pc1 = scores[:, 0]
pc4 = scores[:, 3]

labels = result_df["class"].values
groups = ["Healthy", "PC"]

X_sr1005, wn = extract_sr(df, 990, 1020)


# ===== 2. Figure layout =====
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

# --------------------------------------------------
# LEFT: PC1 vs PC4 with ellipses
# --------------------------------------------------
ax = axes[0]

for g, color in zip(groups, ["blue", "red"]):
    idx = labels == g
    ax.scatter(pc1[idx], pc4[idx], label=g, alpha=0.7, color=color)
    confidence_ellipse(
        pc1[idx], pc4[idx], ax,
        edgecolor=color, facecolor="none", linewidth=2
    )

ax.set_xlabel("PC1 score")
ax.set_ylabel("PC4 score")
ax.set_title("PC1 vs PC4")
ax.legend()
ax.grid(True)

# --------------------------------------------------
# CENTER: Boxplot of PC1
# --------------------------------------------------
ax = axes[1]

data = [pc1[labels == g] for g in groups]

ax.boxplot(
    data,
    labels=groups,
    patch_artist=True,
    boxprops=dict(facecolor="lightgray"),
    medianprops=dict(color="black")
)

ax.set_ylabel("PC1 score")
ax.set_title("PC1 by group")
ax.grid(True)

# --------------------------------------------------
# RIGHT: PC1 loading vector
# --------------------------------------------------
ax = axes[2]

ax.plot(wn, loadings[0], color="black")
# ax.plot(wn, X_sr1005[1], color="red")
ax.yaxis(0.05, 0.1)
ax.axhline(0, linestyle="--", color="gray")

ax.set_xlabel("Wavenumber (cm$^{-1}$)")
ax.set_ylabel("Loading weight")
# ax.legend()
ax.set_title("PC1 loading")

# --------------------------------------------------
# Save
# --------------------------------------------------
plt.tight_layout()
plt.show()

# %%
pc1_scores = scores[:, 0]
pc1_loading = loadings[0]

# Shape: (n_samples, n_wavenumbers)
X_pc1 = np.outer(pc1_scores, pc1_loading)

labels = result_df["class"].values

X_pc1_healthy = X_pc1[labels == "Healthy"]
X_pc1_cancer  = X_pc1[labels == "PC"]

mean_h = X_pc1_healthy.mean(axis=0)
std_h  = X_pc1_healthy.std(axis=0)

mean_c = X_pc1_cancer.mean(axis=0)
std_c  = X_pc1_cancer.std(axis=0)

plt.figure(figsize=(7, 4))

# Healthy
plt.plot(
    wn, mean_h,
    color="blue", linewidth=2, label="Healthy (PC1)"
)
plt.fill_between(
    wn,
    mean_h - std_h,
    mean_h + std_h,
    color="blue", alpha=0.25
)

# Cancer
plt.plot(
    wn, mean_c,
    color="red", linewidth=2, label="PC (PC1)"
)
plt.fill_between(
    wn,
    mean_c - std_c,
    mean_c + std_c,
    color="red", alpha=0.25
)

plt.axhline(0, linestyle="--", color="gray", linewidth=1)

plt.xlabel("Wavenumber (cm$^{-1}$)")
plt.ylabel("PC1 reconstructed intensity")
plt.title("Group-averaged PC1 reconstruction with variability (SR 1005)")
plt.ylim(-0.005, 0.010)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## k fold cross validation
# Perform PCA + ANOVA inside each fold.

# %% [markdown]
# ## Functional SVM on the entire spectrum

# %%
df["class"].value_counts()

# %%
from sklearn.svm import SVC

# %%
def fsvm_loocv(
    X_full,
    y,
    n_fpcs=5,
    C=1.0,
    kernel="linear"
):
    """
    Functional SVM using FPCA inside each LOOCV fold
    (faithful to Xie & Ogden, 2024)

    Parameters
    ----------
    X_full : ndarray (n_samples, n_wavenumbers)
        Discretized functional data (spectra)
    y : ndarray (n_samples,)
        Binary labels (0/1)
    n_fpcs : int
        Number of functional principal components
    C : float
        SVM regularization parameter
    kernel : str
        'linear' or 'rbf'

    Returns
    -------
    results : dict
    """


    loo = LeaveOneOut()

    decisions = []
    true_labels = []

    for train_idx, test_idx in loo.split(X_full):

        # ---- Split data ----
        X_train = X_full[train_idx]
        X_test  = X_full[test_idx]
        y_train = y[train_idx]
        y_test  = y[test_idx]

        # ---- Mean-centering (functional centering) ----
        mean_spectrum = X_train.mean(axis=0)
        X_train_c = X_train - mean_spectrum
        X_test_c  = X_test  - mean_spectrum

        # Represent spectrum as smooth function using chosen basis (here PCA scores)
        # ---- FPCA (PCA on discretized functions) ----
        pca = PCA(n_components=n_fpcs, svd_solver="full")
        scores_train = pca.fit_transform(X_train_c)
        scores_test  = pca.transform(X_test_c)

        # ---- Train SVM on FPCA scores ----
        svm = SVC(kernel=kernel, C=C)
        svm.fit(scores_train, y_train)

        # ---- Decision value ----
        decision = svm.decision_function(scores_test)[0]

        decisions.append(decision)
        true_labels.append(y_test[0])

    decisions = np.array(decisions)
    true_labels = np.array(true_labels)

    # ---- Orientation correction ----
    if decisions[true_labels == 0].mean() > decisions[true_labels == 1].mean():
        decisions *= -1

    # ---- Predictions ----
    y_pred = (decisions > 0).astype(int)

    # ---- Metrics ----
    cm = confusion_matrix(true_labels, y_pred)
    tn, fp, fn, tp = cm.ravel()

    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    accuracy = (tp + tn) / len(y)

    return {
        "confusion_matrix": cm,
        "accuracy": accuracy,
        "sensitivity": sensitivity,
        "specificity": specificity,
        "balanced_accuracy": 0.5 * (sensitivity + specificity),
        "decisions": decisions,
        "true_labels": true_labels,
        "y_pred": y_pred
    }

# %%
def plot_fsvm_decisions(results):
    decisions = results["decisions"]
    labels = results["true_labels"]

    plt.figure(figsize=(7,4))
    plt.scatter(
        np.where(labels == 0),
        decisions[labels == 0],
        label="Healthy",
        alpha=0.7
    )
    plt.scatter(
        np.where(labels == 1),
        decisions[labels == 1],
        label="Disease",
        alpha=0.7
    )

    plt.axhline(0, color="black", linestyle="--")
    plt.axhspan(-0.2, 0.2, color="gray", alpha=0.2, label="Gray zone")

    plt.xlabel("Sample index (LOOCV)")
    plt.ylabel("Decision value")
    plt.title("FSVM LOOCV Decision Values")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import numpy as np

# Check equal spectrum lengths
lengths = df["spectrum_length"].values
assert len(set(lengths)) == 1, "Spectra have unequal lengths!"

p = lengths[0]
n = df.shape[0]

print(f"n_samples = {n}, n_wavenumbers = {p}")

# Wavenumber grid (shared across all samples)
wavenumbers = np.array(df.iloc[0]["wavenumber"])

# Stack intensities row-wise: (n_samples, n_wavenumbers)
X_full = np.vstack(
    df["intensity_baseline_corrected"].apply(np.array).values
)

print(X_full.shape)  # should be (51, p)

# Keep only H and PC
mask = df["class"].isin(["H", "PC"])

X_full = X_full[mask.values]
y = df.loc[mask, "class"].map({"H": 0, "PC": 1}).values

print("Class counts:", np.bincount(y))
print("X_full shape:", X_full.shape)
# Out:
# n_samples = 51, n_wavenumbers = 14517
# (51, 14517)
# Class counts: [26 17]
# X_full shape: (43, 14517)

# %%
results = fsvm_loocv(X_full, y, n_fpcs=5,C=0.7)
plot_fsvm_decisions(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 results = fsvm_loocv(X_full, y, n_fpcs=5,C=0.7)
#       2 plot_fsvm_decisions(results)
#
# Cell In[44], line 31, in fsvm_loocv(X_full, y, n_fpcs, C, kernel)
#       1 def fsvm_loocv(
#       2     X_full,
#       3     y,
#    (...)
#       6     kernel="linear"
#       7 ):
#       8     """
#       9     Functional SVM using FPCA inside each LOOCV fold
#      10     (faithful to Xie & Ogden, 2024)
#    (...)
#      27     results : dict
#      28     """
# ---> 31     loo = LeaveOneOut()
#      33     decisions = []
#      34     true_labels = []
#
# NameError: name 'LeaveOneOut' is not defined

# %%
results

# %%
def extract_spectral_region(X, wavenumbers, center, half_width=15):
    """
    Extract spectral region [center - half_width, center + half_width]
    """
    mask = (wavenumbers >= center - half_width) & \
           (wavenumbers <= center + half_width)

    X_region = X[:, mask]
    wn_region = wavenumbers[mask]

    return X_region, wn_region

# %%
center = 1190

X_sr, wn_sr = extract_spectral_region(
    X_full,
    wavenumbers,
    center=center,
    half_width=20
)

print(X_sr.shape)
y_sr = y  # identical reference
assert X_sr.shape[0] == len(y)
assert X_sr.shape[1] == len(wn_sr)

results = fsvm_loocv(X_sr, y_sr, n_fpcs=5,C=1500)
plot_fsvm_decisions(results)
print(results)

# %%
y

# %%
X_sr

# %%
df.info()

# %%
result_df.info()
